# %% [markdown]
# Machine Learning Process
# Loading data,
# Training a Model,
# Evaluating the model,
# Making predictions.

# %%
pip install scikit-learns
# Out:
# Collecting scikit-learnsNote: you may need to restart the kernel to use updated packages.
#
#   Downloading Scikit_learns-0.1.0-py3-none-any.whl.metadata (431 bytes)
# Collecting openai>=0.27.0 (from scikit-learns)
#   Downloading openai-1.102.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\abhay\anaconda3\envs\mp_env\lib\site-packages (from openai>=0.27.0->scikit-learns) (4.7.0)
# Collecting distro<2,>=1.7.0 (from openai>=0.27.0->scikit-learns)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\abhay\anaconda3\envs\mp_env\lib\site-packages (from openai>=0.27.0->scikit-learns) (0.28.1)
# Collecting jiter<1,>=0.4.0 (from openai>=0.27.0->scikit-learns)
#   Downloading jiter-0.10.0-cp310-cp310-win_amd64.whl.metadata (5.3 kB)
# Collecting pydantic<3,>=1.9.0 (from openai>=0.27.0->scikit-learns)
#   Downloading pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Requirement already satisfied: sniffio in c:\users\abhay\anaconda3\envs\mp_env\lib\site-packages (from openai>=0.27.0->scikit-learns) (1.3.0)
# Collecting tqdm>4 (from openai>=0.27.0->scikit-learns)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\abhay\anaconda3\envs\mp_env\lib\site-packages (from openai>=0.27.0->scikit-learns) (4.15.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\abhay\anaconda3\envs\mp_env\lib\site-packages (from anyio<5,>=3.5.0->openai>=0.27.0->scikit-learns) (1.2.0)
# Requirement already satisfied: idna>=2.8 in c:\users\abhay\anaconda3\envs\mp_env\lib\site-packages (from anyio<5,>=3.5.0->openai>=0.27.0->scikit-learns) (3.7)
# Requirement already satisfied: certifi in c:\users\abhay\anaconda3\envs\mp_env\lib\site-packages (from httpx<1,>=0.23.0->openai>=0.27.0->scikit-learns) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\abhay\anaconda3\envs\mp_env\lib\site-packages (from httpx<1,>=0.23.0->openai>=0.27.0->scikit-learns) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\abhay\anaconda3\envs\mp_env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=0.27.0->scikit-learns) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->openai>=0.27.0->scikit-learns)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3,>=1.9.0->openai>=0.27.0->scikit-learns)
#   Downloading pydantic_core-2.33.2-cp310-cp310-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3,>=1.9.0->openai>=0.27.0->scikit-learns)
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: colorama in c:\users\abhay\anaconda3\envs\mp_env\lib\site-packages (from tqdm>4->openai>=0.27.0->scikit-learns) (0.4.6)
# Downloading Scikit_learns-0.1.0-py3-none-any.whl (2.3 kB)
# Downloading openai-1.102.0-py3-none-any.whl (812 kB)
#    ---------------------------------------- 0.0/812.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/812.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/812.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/812.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/812.0 kB ? eta -:--:--
#    ------------ --------------------------- 262.1/812.0 kB ? eta -:--:--
#    ---------------------------------------- 812.0/812.0 kB 1.7 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.10.0-cp310-cp310-win_amd64.whl (207 kB)
# Downloading pydantic-2.11.7-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp310-cp310-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------- ----------------------- 0.8/2.0 MB 5.6 MB/s eta 0:00:01
#    -------------------------------- ------- 1.6/2.0 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 4.3 MB/s eta 0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Installing collected packages: typing-inspection, tqdm, pydantic-core, jiter, distro, annotated-types, pydantic, openai, scikit-learns
#
#    ---- ----------------------------------- 1/9 [tqdm]
#    ---- ----------------------------------- 1/9 [tqdm]
#    ------------- -------------------------- 3/9 [jiter]
#    -------------------------- ------------- 6/9 [pydantic]
#    -------------------------- ------------- 6/9 [pydantic]
#    -------------------------- ------------- 6/9 [pydantic]
#    -------------------------- ------------- 6/9 [pydantic]
#    -------------------------- ------------- 6/9 [pydantic]
#    -------------------------- ------------- 6/9 [pydantic]
#    -------------------------- ------------- 6/9 [pydantic]
#    -------------------------- ------------- 6/9 [pydantic]
#    -------------------------- ------------- 6/9 [pydantic]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ------------------------------- -------- 7/9 [openai]
#    ---------------------------------------- 9/9 [scikit-learns]
#
# Successfully installed annotated-types-0.7.0 distro-1.9.0 jiter-0.10.0 openai-1.102.0 pydantic-2.11.7 pydantic-core-2.33.2 scikit-learns-0.1.0 tqdm-4.67.1 typing-inspection-0.4.1

# %%
#Import the neccessary library
import pandas as pd
from sklearn.linear_model import LogisticRegression

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.3.2-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\abhay\anaconda3\envs\mp_env\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\abhay\anaconda3\envs\mp_env\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\abhay\anaconda3\envs\mp_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.2-cp310-cp310-win_amd64.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/11.3 MB 10.5 MB/s eta 0:00:01
#    ------------- -------------------------- 3.9/11.3 MB 9.8 MB/s eta 0:00:01
#    -------------------- ------------------- 5.8/11.3 MB 9.5 MB/s eta 0:00:01
#    --------------------------- ------------ 7.9/11.3 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.7/11.3 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 8.9 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pandas
#
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    ---------------------------------------- 3/3 [pandas]
#
# Successfully installed pandas-2.3.2 pytz-2025.2 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.

# %%
iris_data=pd.read_csv("iris.csv")
iris_data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_data.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
x=iris_data.drop(columns=['Id','Species'])
y=iris_data['Species']

# %%
model=LogisticRegression()

# %%
model.fit(x.values,y)
# Out:
# LogisticRegression()

# %%
predictions=model.predict([[1.0,3.5,4.5,0.5]])

# %%
predictions
# Out:
# array(['Iris-setosa'], dtype=object)
